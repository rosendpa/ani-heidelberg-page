# %%
time_continue = time()
locked = False
def getAnime(malid,i=0):
    global time_continue
    global locked
    global head_thread
    time_start = time()
    maldata = None
    while maldata is None:
        sleep(1)
        timeout = time_continue-time()
        while locked: #while blocked
            if i == head_thread: #only head should test if unblocked
                if time_continue < time():
                    print("")
                    break 
                else:
                    print(".", end="")   
                    sleep(timeout/75)
            else:
                sleep(5)
                
        try:
            maldata = Anime(malid, timeout=10)
        except Exception as e:
            print("")
            locked = True
            timeout = min(max((time()-time_start)//10*10,10),1200) 
            time_continue = time() + timeout
            #print(f"Fehler: {e}  Versuche nochmal in {int(timeout)} sec..")
            print(f"[{i}] {e}, wait {int(timeout)}s")
    locked = False    
    time_continue = time() #reset timeout if successful
    return maldata


def one_cleanup(old, clean, i, mal):
    try:
        if mal: #force update from mal
            a=1/0 #go to except
        if min([len(str(s)) for s in list(old.values())])==0: #missing entries
            a=1/0
        if old["progr"][-2]=="?": #unknown episode count
            a=1/0 
        #load old data, maybe there are missing keys
        tmp = {"index":old["index"], "malid":old["malid"], "title":old["title"], "titen":old["titen"], "titjp":old["titjp"],"theme":old["theme"],"imurl":old["imurl"],"semes":old["semes"],"progr":old["progr"],"vdate":old["vdate"],"statu":old["statu"]}
    except Exception as es:
        if not mal: 
            print(f"Ungültiger Eintrag (id:{old['malid']}) entdeckt, lade neu von MAL.. ({es})")

        maldata = getAnime(old["malid"],i)

        tmp = {"index":old["index"], 
               "malid":old["malid"],
               "title":maldata.title,
               "titen":maldata.title_english,
               "titjp":maldata.title_japanese,
               "theme":", ".join(maldata.genres),
               "imurl":maldata.image_url.replace(".jpg","l.jpg").replace("ll.jpg","l.jpg"), #get large picture
               "semes":old["semes"],
               "progr":("00"+old["progr"][:2].replace("/",""))[-2:]+"/"+("00"+str(maldata.episodes).replace("None","??"))[-2:],
               "vdate":old["vdate"],
               "statu":old["statu"]
               }
        #leere Einträge verhindern
        if tmp["titen"] in ["null", None, False, ""]:
            tmp["titen"] = tmp["title"]
        if tmp["theme"] in ["null", None, False, ""]:
            tmp["theme"] = " "
    #print("")
    #print(f"{tmp['index']} ", end="")
    print(f"{tmp['title']}\n", end="") 
    #print(tmp["titen"])
    #print(tmp["titjp"])
    #print(tmp["theme"])
    #print(tmp["statu"], tmp["progr"])
    #print("")
    #print("")
    clean[i] = tmp
    
def sort_index(entry):
    if entry["statu"] == "W":
        return 0
    else:
        return int(entry["index"])
        #return int(entry["progr"][:2])
        #return int("".join(entry["vdate"].split(".")[::-1]))
    
head_thread = 0
def list_cleanup(data, mal=False):
    clean = [{} for i in data]
    threads = []
    
    for i in range(len(data)):
        #threads.append(Thread(target=call_script, args=(11.0,)))
        threads.append(Thread(target=one_cleanup, args = (data[i], clean, i, mal)))
     
    if mal:
        print("API request sent, waiting for replies:")
    
    for t in threads:
        sleep(.05)
        t.start()
        
    for i in range(len(threads)):
        global head_thread
        head_thread = i
        threads[i].join()
        
    clean = sorted(clean, key=sort_index)
    return clean

# %%
list_cleanup(data, False)
# Out:
# Chuunibyou demo Koi ga Shitai! Ren
# Kokoro Connect
# Fate/Zero
# Fate/Zero 2nd Season
# Danshi Koukousei no Nichijou
# Zankyou no Terror
# Tokyo Ghoul
# Kaichou wa Maid-sama!
# Sidonia no Kishi
# Shinsekai yori
# Girls & Panzer
# Gekkan Shoujo Nozaki-kun
# Fate/stay night: Unlimited Blade Works
# Tokyo Ghoul √A
# Uchuu Senkan Yamato 2199
# NHK ni Youkoso!
# Usagi Drop
# Genshiken
# Fate/stay night: Unlimited Blade Works 2nd Season
# Perfect Blue
# Ookami to Koushinryou
# Durarara!!
# Hataraku Maou-sama!
# Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.
# One Punch Man
# Boku dake ga Inai Machi
# Psycho-Pass
# Subete ga F ni Naru
# Shirobako
# Katanagatari
# Koutetsujou no Kabaneri
# Kobayashi-san Chi no Maid Dragon
# Little Witch Academia (TV)
# Natsume Yuujinchou
# Amaama to Inazuma
# Youjo Senki
# Nejimaki Seirei Senki: Tenkyou no Alderamin
# Planetes
# Re:Zero kara Hajimeru Isekai Seikatsu
# 91 Days
# Hyouka
# Jormungand
# Re:Creators
# Hibike! Euphonium
# Full Metal Panic!
# Demi-chan wa Kataritai
# Mahoutsukai no Yome
# Mushishi
# Made in Abyss
# Yuri!!! on Ice
# Kono Subarashii Sekai ni Shukufuku wo!
# Sora yori mo Tooi Basho
# Takunomi.
# Koukaku Kidoutai: Stand Alone Complex
# Mirai Nikki (TV)
# Steins;Gate
# Hetalia Axis Powers
# Hinamatsuri (TV)
# Irozuku Sekai no Ashita kara
# Zombieland Saga
# Dororo
# Yakusoku no Neverland
# Houseki no Kuni (TV)
# Suzumiya Haruhi no Yuuutsu
# Araburu Kisetsu no Otome-domo yo.
# Shoujo Shuumatsu Ryokou
# Isekai Quartet
# Fruits Basket 1st Season
# Vinland Saga
# Kimetsu no Yaiba
# Rikei ga Koi ni Ochita no de Shoumei shitemita.
# Isekai Quartet 2
# Ore wo Suki nano wa Omae dake ka yo
# Elfen Lied
# Id:Invaded
# Kill la Kill
# Mawaru Penguindrum
# Otome Game no Hametsu Flag shika Nai Akuyaku Reijou ni Tensei shiteshimatta...
# Itai no wa Iya nano de Bougyoryoku ni Kyokufuri Shitai to Omoimasu.
# JoJo no Kimyou na Bouken (TV)
# Black Lagoon
# Golden Kamuy
# Kaguya-sama wa Kokurasetai: Tensai-tachi no Renai Zunousen
# Kaguya-sama wa Kokurasetai?: Tensai-tachi no Renai Zunousen
# Black Lagoon: The Second Barrage
# Amagi Brilliant Park
# Deadman Wonderland
# Wonder Egg Priority
# Yakusoku no Neverland 2nd Season
# Eizouken ni wa Te wo Dasu na!
# Zombieland Saga: Revenge
# 86
# Ben-To
# Otome Game no Hametsu Flag shika Nai Akuyaku Reijou ni Tensei shiteshimatta... X
# Fumetsu no Anata e
# Kimetsu no Yaiba: Mugen Ressha-hen
# Shiroi Suna no Aquatope
# 86 Part 2
# Tsuki to Laika to Nosferatu
# Kimetsu no Yaiba: Yuukaku-hen
# Clannad
# Mushoku Tensei: Isekai Ittara Honki Dasu
# Kuragehime
# [{'index': '100',
#   'malid': '47778',
#   'title': 'Kimetsu no Yaiba: Yuukaku-hen',
#   'titen': 'Demon Slayer: Kimetsu no Yaiba Entertainment District Arc',
#   'titjp': '鬼滅の刃 遊郭編',
#   'theme': 'Action, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1908/120036l.jpg',
#   'semes': '21W',
#   'progr': '09/11',
#   'vdate': '23.02.2022',
#   'statu': 'W'},
#  {'index': '103',
#   'malid': '2167',
#   'title': 'Clannad',
#   'titen': 'Clannad',
#   'titjp': 'CLANNAD',
#   'theme': 'Comedy, Drama, Romance, Slice of Life, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1804/95033l.jpg',
#   'semes': '21W',
#   'progr': '05/23',
#   'vdate': '23.02.2022',
#   'statu': 'W'},
#  {'index': '101',
#   'malid': '39535',
#   'title': 'Mushoku Tensei: Isekai Ittara Honki Dasu',
#   'titen': 'Mushoku Tensei: Jobless Reincarnation',
#   'titjp': '無職転生 ～異世界行ったら本気だす～',
#   'theme': 'Drama, Fantasy, Ecchi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1530/117776l.jpg',
#   'semes': '21W',
#   'progr': '07/11',
#   'vdate': '23.02.2022',
#   'statu': 'W'},
#  {'index': '102',
#   'malid': '8129',
#   'title': 'Kuragehime',
#   'titen': 'Princess Jellyfish',
#   'titjp': '海月姫',
#   'theme': 'Comedy, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/3/24865l.jpg',
#   'semes': '21W',
#   'progr': '07/11',
#   'vdate': '23.02.2022',
#   'statu': 'W'},
#  {'index': '20',
#   'malid': '437',
#   'title': 'Perfect Blue',
#   'titen': 'Perfect Blue',
#   'titjp': 'パーフェクトブルー',
#   'theme': 'Avant Garde, Drama, Horror',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/11/79127l.jpg',
#   'semes': '15S',
#   'progr': '01/01',
#   'vdate': '10.06.2015',
#   'statu': 'F'},
#  {'index': '14',
#   'malid': '27899',
#   'title': 'Tokyo Ghoul √A',
#   'titen': 'Tokyo Ghoul √A',
#   'titjp': '東京喰種√A',
#   'theme': 'Action, Drama, Horror, Mystery, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/13/71777l.jpg',
#   'semes': '14W',
#   'progr': '02/12',
#   'vdate': '04.02.2015',
#   'statu': 'D'},
#  {'index': '98',
#   'malid': '49926',
#   'title': 'Kimetsu no Yaiba: Mugen Ressha-hen',
#   'titen': 'Demon Slayer: Kimetsu no Yaiba Mugen Train Arc',
#   'titjp': '鬼滅の刃 無限列車編',
#   'theme': 'Action, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1065/118763l.jpg',
#   'semes': '21W',
#   'progr': '07/07',
#   'vdate': '08.12.2021',
#   'statu': 'F'},
#  {'index': '51',
#   'malid': '30831',
#   'title': 'Kono Subarashii Sekai ni Shukufuku wo!',
#   'titen': "KonoSuba: God's Blessing on This Wonderful World!",
#   'titjp': 'この素晴らしい世界に祝福を！',
#   'theme': 'Adventure, Comedy, Fantasy, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/8/77831l.jpg',
#   'semes': '18S',
#   'progr': '10/10',
#   'vdate': '08.08.2018',
#   'statu': 'F'},
#  {'index': '97',
#   'malid': '48569',
#   'title': '86 Part 2',
#   'titen': '86 Eighty-Six',
#   'titjp': '86―エイティシックス―',
#   'theme': 'Action, Drama, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1321/117508l.jpg',
#   'semes': '21W',
#   'progr': '10/12',
#   'vdate': '05.01.2022',
#   'statu': 'D'},
#  {'index': '6',
#   'malid': '23283',
#   'title': 'Zankyou no Terror',
#   'titen': 'Terror in Resonance',
#   'titjp': '残響のテロル',
#   'theme': 'Mystery, Suspense',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1417/117422l.jpg',
#   'semes': '14S',
#   'progr': '11/11',
#   'vdate': '05.11.2014',
#   'statu': 'F'},
#  {'index': '17',
#   'malid': '10162',
#   'title': 'Usagi Drop',
#   'titen': 'Bunny Drop',
#   'titjp': 'うさぎドロップ',
#   'theme': 'Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/2/29665l.jpg',
#   'semes': '15S',
#   'progr': '11/11',
#   'vdate': '01.07.2015',
#   'statu': 'F'},
#  {'index': '24',
#   'malid': '9989',
#   'title': 'Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.',
#   'titen': 'anohana: The Flower We Saw That Day',
#   'titjp': 'あの日見た花の名前を僕達はまだ知らない。',
#   'theme': 'Drama, Slice of Life, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/79697l.jpg',
#   'semes': '15W',
#   'progr': '11/11',
#   'vdate': '27.01.2016',
#   'statu': 'F'},
#  {'index': '28',
#   'malid': '28621',
#   'title': 'Subete ga F ni Naru',
#   'titen': 'The Perfect Insider',
#   'titjp': 'すべてがFになる THE PERFECT INSIDER',
#   'theme': 'Mystery, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/9/76071l.jpg',
#   'semes': '15W',
#   'progr': '11/11',
#   'vdate': '20.01.2016',
#   'statu': 'F'},
#  {'index': '89',
#   'malid': '39617',
#   'title': 'Yakusoku no Neverland 2nd Season',
#   'titen': 'The Promised Neverland Season 2',
#   'titjp': '約束のネバーランド',
#   'theme': 'Mystery, Sci-Fi, Suspense',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1815/110626l.jpg',
#   'semes': '20W',
#   'progr': '11/11',
#   'vdate': '31.03.2021',
#   'statu': 'F'},
#  {'index': '92',
#   'malid': '41457',
#   'title': '86',
#   'titen': '86',
#   'titjp': '86―エイティシックス―',
#   'theme': 'Action, Drama, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1987/117507l.jpg',
#   'semes': '21S',
#   'progr': '11/11',
#   'vdate': '28.07.2021',
#   'statu': 'F'},
#  {'index': '1',
#   'malid': '18671',
#   'title': 'Chuunibyou demo Koi ga Shitai! Ren',
#   'titen': 'Love, Chunibyo & Other Delusions!: Heart Throb',
#   'titjp': '中二病でも恋がしたい！戀',
#   'theme': 'Comedy, Drama, Romance, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/7/56643l.jpg',
#   'semes': '13W',
#   'progr': '12/12',
#   'vdate': '02.04.2014',
#   'statu': 'F'},
#  {'index': '4',
#   'malid': '11741',
#   'title': 'Fate/Zero 2nd Season',
#   'titen': 'Fate/Zero Season 2',
#   'titjp': 'フェイト/ゼロ 2ndシーズン',
#   'theme': 'Action, Fantasy, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1522/117645l.jpg',
#   'semes': '13W',
#   'progr': '12/12',
#   'vdate': '02.04.2014',
#   'statu': 'F'},
#  {'index': '5',
#   'malid': '11843',
#   'title': 'Danshi Koukousei no Nichijou',
#   'titen': 'Daily Lives of High School Boys',
#   'titjp': '男子高校生の日常',
#   'theme': 'Comedy, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/3/33257l.jpg',
#   'semes': '14S',
#   'progr': '12/12',
#   'vdate': '05.11.2014',
#   'statu': 'F'},
#  {'index': '7',
#   'malid': '22319',
#   'title': 'Tokyo Ghoul',
#   'titen': 'Tokyo Ghoul',
#   'titjp': '東京喰種-トーキョーグール-',
#   'theme': 'Action, Drama, Horror, Mystery, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/64449l.jpg',
#   'semes': '14S',
#   'progr': '12/12',
#   'vdate': '15.10.2014',
#   'statu': 'F'},
#  {'index': '9',
#   'malid': '19775',
#   'title': 'Sidonia no Kishi',
#   'titen': 'Knights of Sidonia',
#   'titjp': 'シドニアの騎士',
#   'theme': 'Action, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/12/53257l.jpg',
#   'semes': '14S',
#   'progr': '12/12',
#   'vdate': '02.07.2014',
#   'statu': 'F'},
#  {'index': '11',
#   'malid': '14131',
#   'title': 'Girls & Panzer',
#   'titen': 'Girls & Panzer',
#   'titjp': 'ガールズ&パンツァー',
#   'theme': 'Action, Sports',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/9/40969l.jpg',
#   'semes': '14W',
#   'progr': '12/12',
#   'vdate': '21.01.2015',
#   'statu': 'F'},
#  {'index': '12',
#   'malid': '23289',
#   'title': 'Gekkan Shoujo Nozaki-kun',
#   'titen': "Monthly Girls' Nozaki-kun",
#   'titjp': '月刊少女野崎くん',
#   'theme': 'Comedy, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/66083l.jpg',
#   'semes': '14W',
#   'progr': '12/12',
#   'vdate': '22.04.2015',
#   'statu': 'F'},
#  {'index': '13',
#   'malid': '22297',
#   'title': 'Fate/stay night: Unlimited Blade Works',
#   'titen': 'Fate/stay night [Unlimited Blade Works]',
#   'titjp': 'Fate/stay night [Unlimited Blade Works]',
#   'theme': 'Action, Fantasy, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/12/67333l.jpg',
#   'semes': '14W',
#   'progr': '12/12',
#   'vdate': '14.01.2015',
#   'statu': 'F'},
#  {'index': '18',
#   'malid': '240',
#   'title': 'Genshiken',
#   'titen': 'Genshiken',
#   'titjp': 'げんしけん',
#   'theme': 'Comedy, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1890/94707l.jpg',
#   'semes': '15S',
#   'progr': '12/12',
#   'vdate': '23.09.2015',
#   'statu': 'F'},
#  {'index': '25',
#   'malid': '30276',
#   'title': 'One Punch Man',
#   'titen': 'One Punch Man',
#   'titjp': 'ワンパンマン',
#   'theme': 'Action, Comedy, Sci-Fi, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/12/76049l.jpg',
#   'semes': '15W',
#   'progr': '12/12',
#   'vdate': '13.01.2016',
#   'statu': 'F'},
#  {'index': '26',
#   'malid': '31043',
#   'title': 'Boku dake ga Inai Machi',
#   'titen': 'ERASED',
#   'titjp': '僕だけがいない街',
#   'theme': 'Mystery, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/10/77957l.jpg',
#   'semes': '15W',
#   'progr': '12/12',
#   'vdate': '06.04.2016',
#   'statu': 'F'},
#  {'index': '30',
#   'malid': '6594',
#   'title': 'Katanagatari',
#   'titen': 'Katanagatari',
#   'titjp': '刀語',
#   'theme': 'Action, Adventure, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1112/119225l.jpg',
#   'semes': '16S',
#   'progr': '12/12',
#   'vdate': '20.07.2016',
#   'statu': 'F'},
#  {'index': '31',
#   'malid': '28623',
#   'title': 'Koutetsujou no Kabaneri',
#   'titen': 'Kabaneri of the Iron Fortress',
#   'titjp': '甲鉄城のカバネリ',
#   'theme': 'Action, Drama, Fantasy, Horror, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/12/79164l.jpg',
#   'semes': '16S',
#   'progr': '12/12',
#   'vdate': '13.07.2016',
#   'statu': 'F'},
#  {'index': '35',
#   'malid': '32828',
#   'title': 'Amaama to Inazuma',
#   'titen': 'Sweetness & Lightning',
#   'titjp': '甘々と稲妻',
#   'theme': 'Comedy, Gourmet, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/6/80546l.jpg',
#   'semes': '16S',
#   'progr': '12/12',
#   'vdate': '26.10.2016',
#   'statu': 'F'},
#  {'index': '36',
#   'malid': '32615',
#   'title': 'Youjo Senki',
#   'titen': 'Saga of Tanya the Evil',
#   'titjp': '幼女戦記',
#   'theme': 'Action',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/82890l.jpg',
#   'semes': '16W',
#   'progr': '12/12',
#   'vdate': '10.05.2017',
#   'statu': 'F'},
#  {'index': '40',
#   'malid': '32998',
#   'title': '91 Days',
#   'titen': '91 Days',
#   'titjp': '91Days',
#   'theme': 'Action, Drama',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/13/80515l.jpg',
#   'semes': '16S',
#   'progr': '12/12',
#   'vdate': '19.10.2016',
#   'statu': 'F'},
#  {'index': '42',
#   'malid': '12413',
#   'title': 'Jormungand',
#   'titen': 'Jormungand',
#   'titjp': 'ヨルムンガンド',
#   'theme': 'Action, Adventure',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/11/73280l.jpg',
#   'semes': '17S',
#   'progr': '12/12',
#   'vdate': '23.08.2017',
#   'statu': 'F'},
#  {'index': '46',
#   'malid': '33988',
#   'title': 'Demi-chan wa Kataritai',
#   'titen': 'Interviews With Monster Girls',
#   'titjp': '亜人ちゃんは語りたい',
#   'theme': 'Comedy, Fantasy',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/8/83417l.jpg',
#   'semes': '17S',
#   'progr': '12/12',
#   'vdate': '22.11.2017',
#   'statu': 'F'},
#  {'index': '50',
#   'malid': '32995',
#   'title': 'Yuri!!! on Ice',
#   'titen': 'Yuri!!! On ICE',
#   'titjp': 'ユーリ!!! on ICE',
#   'theme': 'Comedy, Sports',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/6/81149l.jpg',
#   'semes': '18S',
#   'progr': '12/12',
#   'vdate': '07.11.2018',
#   'statu': 'F'},
#  {'index': '53',
#   'malid': '36108',
#   'title': 'Takunomi.',
#   'titen': 'Takunomi',
#   'titjp': 'たくのみ。',
#   'theme': 'Comedy, Gourmet, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1869/95731l.jpg',
#   'semes': '17W',
#   'progr': '12/12',
#   'vdate': '06.06.2018',
#   'statu': 'F'},
#  {'index': '58',
#   'malid': '36296',
#   'title': 'Hinamatsuri (TV)',
#   'titen': 'Hinamatsuri',
#   'titjp': 'ヒナまつり',
#   'theme': 'Comedy, Sci-Fi, Slice of Life, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1580/93526l.jpg',
#   'semes': '18W',
#   'progr': '12/12',
#   'vdate': '29.05.2019',
#   'statu': 'F'},
#  {'index': '60',
#   'malid': '37976',
#   'title': 'Zombieland Saga',
#   'titen': 'Zombie Land Saga',
#   'titjp': 'ゾンビランドサガ',
#   'theme': 'Comedy, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1094/95453l.jpg',
#   'semes': '18W',
#   'progr': '12/12',
#   'vdate': '16.01.2019',
#   'statu': 'F'},
#  {'index': '62',
#   'malid': '37779',
#   'title': 'Yakusoku no Neverland',
#   'titen': 'The Promised Neverland',
#   'titjp': '約束のネバーランド',
#   'theme': 'Horror, Mystery, Sci-Fi, Suspense',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1830/118780l.jpg',
#   'semes': '18W',
#   'progr': '12/12',
#   'vdate': '10.04.2019',
#   'statu': 'F'},
#  {'index': '63',
#   'malid': '35557',
#   'title': 'Houseki no Kuni (TV)',
#   'titen': 'Land of the Lustrous',
#   'titjp': '宝石の国',
#   'theme': 'Action, Drama, Fantasy, Mystery',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/3/88293l.jpg',
#   'semes': '18W',
#   'progr': '12/12',
#   'vdate': '13.02.2019',
#   'statu': 'F'},
#  {'index': '65',
#   'malid': '38753',
#   'title': 'Araburu Kisetsu no Otome-domo yo.',
#   'titen': 'O Maidens in Your Savage Season',
#   'titjp': '荒ぶる季節の乙女どもよ。',
#   'theme': 'Comedy, Drama, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1622/111483l.jpg',
#   'semes': '19S',
#   'progr': '12/12',
#   'vdate': '23.10.2019',
#   'statu': 'F'},
#  {'index': '66',
#   'malid': '35838',
#   'title': 'Shoujo Shuumatsu Ryokou',
#   'titen': "Girls' Last Tour",
#   'titjp': '少女終末旅行',
#   'theme': 'Adventure, Mystery, Sci-Fi, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/12/88321l.jpg',
#   'semes': '19S',
#   'progr': '12/12',
#   'vdate': '18.09.2019',
#   'statu': 'F'},
#  {'index': '67',
#   'malid': '38472',
#   'title': 'Isekai Quartet',
#   'titen': 'Isekai Quartet',
#   'titjp': '異世界かるてっと',
#   'theme': 'Comedy, Fantasy',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1965/99667l.jpg',
#   'semes': '19S',
#   'progr': '12/12',
#   'vdate': '17.07.2019',
#   'statu': 'F'},
#  {'index': '68',
#   'malid': '38680',
#   'title': 'Fruits Basket 1st Season',
#   'titen': 'Fruits Basket 2019 1st Season',
#   'titjp': 'フルーツバスケット',
#   'theme': 'Comedy, Drama, Romance, Slice of Life, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1447/99827l.jpg',
#   'semes': '19S',
#   'progr': '12/25',
#   'vdate': '10.07.2019',
#   'statu': 'D'},
#  {'index': '71',
#   'malid': '38992',
#   'title': 'Rikei ga Koi ni Ochita no de Shoumei shitemita.',
#   'titen': 'Science Fell in Love, So I Tried to Prove It',
#   'titjp': '理系が恋に落ちたので証明してみた。',
#   'theme': 'Comedy, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1432/103533l.jpg',
#   'semes': '19W',
#   'progr': '12/12',
#   'vdate': '20.05.2020',
#   'statu': 'F'},
#  {'index': '72',
#   'malid': '39988',
#   'title': 'Isekai Quartet 2',
#   'titen': 'Isekai Quartet 2',
#   'titjp': '異世界かるてっと2',
#   'theme': 'Comedy, Fantasy',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1030/103383l.jpg',
#   'semes': '19W',
#   'progr': '12/12',
#   'vdate': '29.04.2020',
#   'statu': 'F'},
#  {'index': '73',
#   'malid': '38483',
#   'title': 'Ore wo Suki nano wa Omae dake ka yo',
#   'titen': 'ORESUKI Are you the only one who loves me?',
#   'titjp': '俺を好きなのはお前だけかよ',
#   'theme': 'Comedy, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1348/102797l.jpg',
#   'semes': '19W',
#   'progr': '12/12',
#   'vdate': '05.02.2020',
#   'statu': 'F'},
#  {'index': '78',
#   'malid': '38555',
#   'title': 'Otome Game no Hametsu Flag shika Nai Akuyaku Reijou ni Tensei shiteshimatta...',
#   'titen': 'My Next Life as a Villainess: All Routes Lead to Doom!',
#   'titjp': '乙女ゲームの破滅フラグしかない悪役令嬢に転生してしまった…',
#   'theme': 'Comedy, Drama, Fantasy, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1483/107061l.jpg',
#   'semes': '20S',
#   'progr': '12/12',
#   'vdate': '03.08.2020',
#   'statu': 'F'},
#  {'index': '79',
#   'malid': '38790',
#   'title': 'Itai no wa Iya nano de Bougyoryoku ni Kyokufuri Shitai to Omoimasu.',
#   'titen': "BOFURI: I Don't Want to Get Hurt, so I'll Max Out My Defense.",
#   'titjp': '痛いのは嫌なので防御力に極振りしたいと思います。',
#   'theme': 'Action, Adventure, Comedy, Fantasy, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1579/113812l.jpg',
#   'semes': '20S',
#   'progr': '12/12',
#   'vdate': '04.11.2020',
#   'statu': 'F'},
#  {'index': '81',
#   'malid': '889',
#   'title': 'Black Lagoon',
#   'titen': 'Black Lagoon',
#   'titjp': 'BLACK LAGOON',
#   'theme': 'Action',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/4/25596l.jpg',
#   'semes': '20S',
#   'progr': '12/12',
#   'vdate': '30.09.2020',
#   'statu': 'F'},
#  {'index': '82',
#   'malid': '36028',
#   'title': 'Golden Kamuy',
#   'titen': 'Golden Kamuy',
#   'titjp': 'ゴールデンカムイ',
#   'theme': 'Action, Adventure',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1145/90880l.jpg',
#   'semes': '20S',
#   'progr': '12/12',
#   'vdate': '06.01.2021',
#   'statu': 'F'},
#  {'index': '83',
#   'malid': '37999',
#   'title': 'Kaguya-sama wa Kokurasetai: Tensai-tachi no Renai Zunousen',
#   'titen': 'Kaguya-sama: Love is War',
#   'titjp': 'かぐや様は告らせたい～天才たちの恋愛頭脳戦～',
#   'theme': 'Comedy, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1295/106551l.jpg',
#   'semes': '20W',
#   'progr': '12/12',
#   'vdate': '10.02.2021',
#   'statu': 'F'},
#  {'index': '84',
#   'malid': '40591',
#   'title': 'Kaguya-sama wa Kokurasetai?: Tensai-tachi no Renai Zunousen',
#   'titen': 'Kaguya-sama: Love is War Season 2',
#   'titjp': 'かぐや様は告らせたい？～天才たちの恋愛頭脳戦～',
#   'theme': 'Comedy, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1764/106659l.jpg',
#   'semes': '20W',
#   'progr': '12/12',
#   'vdate': '26.05.2021',
#   'statu': 'F'},
#  {'index': '85',
#   'malid': '1519',
#   'title': 'Black Lagoon: The Second Barrage',
#   'titen': 'Black Lagoon: The Second Barrage',
#   'titjp': 'BLACK LAGOON The Second Barrage',
#   'theme': 'Action',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/3/83748l.jpg',
#   'semes': '20W',
#   'progr': '12/12',
#   'vdate': '06.01.2021',
#   'statu': 'F'},
#  {'index': '87',
#   'malid': '6880',
#   'title': 'Deadman Wonderland',
#   'titen': 'Deadman Wonderland',
#   'titjp': 'デッドマン・ワンダーランド',
#   'theme': 'Action, Horror, Sci-Fi, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/9/75299l.jpg',
#   'semes': '20W',
#   'progr': '12/12',
#   'vdate': '24.03.2021',
#   'statu': 'F'},
#  {'index': '88',
#   'malid': '43299',
#   'title': 'Wonder Egg Priority',
#   'titen': 'Wonder Egg Priority',
#   'titjp': 'ワンダーエッグ・プライオリティ',
#   'theme': 'Drama, Fantasy',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1079/110751l.jpg',
#   'semes': '20W',
#   'progr': '12/12',
#   'vdate': '05.05.2021',
#   'statu': 'F'},
#  {'index': '90',
#   'malid': '39792',
#   'title': 'Eizouken ni wa Te wo Dasu na!',
#   'titen': 'Keep Your Hands Off Eizouken!',
#   'titjp': '映像研には手を出すな!',
#   'theme': 'Adventure, Comedy',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1680/110451l.jpg',
#   'semes': '21S',
#   'progr': '12/12',
#   'vdate': '30.06.2021',
#   'statu': 'F'},
#  {'index': '91',
#   'malid': '40174',
#   'title': 'Zombieland Saga: Revenge',
#   'titen': 'Zombie Land Saga Revenge',
#   'titjp': 'ゾンビランドサガ リベンジ',
#   'theme': 'Comedy, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1118/115156l.jpg',
#   'semes': '21S',
#   'progr': '12/12',
#   'vdate': '07.07.2021',
#   'statu': 'F'},
#  {'index': '93',
#   'malid': '10396',
#   'title': 'Ben-To',
#   'titen': 'Ben-To',
#   'titjp': 'ベン・トー',
#   'theme': 'Action, Comedy, Gourmet',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/12/73984l.jpg',
#   'semes': '21S',
#   'progr': '12/12',
#   'vdate': '29.09.2021',
#   'statu': 'F'},
#  {'index': '94',
#   'malid': '42282',
#   'title': 'Otome Game no Hametsu Flag shika Nai Akuyaku Reijou ni Tensei shiteshimatta... X',
#   'titen': 'My Next Life as a Villainess: All Routes Lead to Doom! X',
#   'titjp': '乙女ゲームの破滅フラグしかない悪役令嬢に転生してしまった…X',
#   'theme': 'Comedy, Drama, Fantasy, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1088/116439l.jpg',
#   'semes': '21S',
#   'progr': '12/12',
#   'vdate': '20.10.2021',
#   'statu': 'F'},
#  {'index': '96',
#   'malid': '48471',
#   'title': 'Tsuki to Laika to Nosferatu',
#   'titen': 'Irina: The Vampire Cosmonaut',
#   'titjp': '月とライカと吸血姫',
#   'theme': 'Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1393/118374l.jpg',
#   'semes': '21W',
#   'progr': '12/12',
#   'vdate': '02.02.2022',
#   'statu': 'F'},
#  {'index': '3',
#   'malid': '10087',
#   'title': 'Fate/Zero',
#   'titen': 'Fate/Zero',
#   'titjp': 'フェイト/ゼロ',
#   'theme': 'Action, Fantasy, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1887/117644l.jpg',
#   'semes': '13W',
#   'progr': '13/13',
#   'vdate': '08.01.2014',
#   'statu': 'F'},
#  {'index': '19',
#   'malid': '28701',
#   'title': 'Fate/stay night: Unlimited Blade Works 2nd Season',
#   'titen': 'Fate/stay night [Unlimited Blade Works] Season 2',
#   'titjp': 'Fate/stay night [Unlimited Blade Works] 2nd シーズン',
#   'theme': 'Action, Fantasy, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/11/72863l.jpg',
#   'semes': '15S',
#   'progr': '13/13',
#   'vdate': '01.07.2015',
#   'statu': 'F'},
#  {'index': '21',
#   'malid': '2966',
#   'title': 'Ookami to Koushinryou',
#   'titen': 'Spice and Wolf',
#   'titjp': '狼と香辛料',
#   'theme': 'Adventure, Fantasy, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/59401l.jpg',
#   'semes': '15S',
#   'progr': '13/13',
#   'vdate': '16.09.2015',
#   'statu': 'F'},
#  {'index': '23',
#   'malid': '15809',
#   'title': 'Hataraku Maou-sama!',
#   'titen': 'The Devil is a Part-Timer!',
#   'titjp': 'はたらく魔王さま!',
#   'theme': 'Comedy, Fantasy, Romance, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/3/50177l.jpg',
#   'semes': '15W',
#   'progr': '13/13',
#   'vdate': '20.04.2016',
#   'statu': 'F'},
#  {'index': '32',
#   'malid': '33206',
#   'title': 'Kobayashi-san Chi no Maid Dragon',
#   'titen': "Miss Kobayashi's Dragon Maid",
#   'titjp': '小林さんちのメイドラゴン',
#   'theme': 'Comedy, Fantasy, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/85434l.jpg',
#   'semes': '16W',
#   'progr': '13/13',
#   'vdate': '17.05.2017',
#   'statu': 'F'},
#  {'index': '34',
#   'malid': '4081',
#   'title': 'Natsume Yuujinchou',
#   'titen': "Natsume's Book of Friends",
#   'titjp': '夏目友人帳',
#   'theme': 'Drama, Slice of Life, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1681/108439l.jpg',
#   'semes': '16W',
#   'progr': '13/13',
#   'vdate': '08.02.2017',
#   'statu': 'F'},
#  {'index': '37',
#   'malid': '31764',
#   'title': 'Nejimaki Seirei Senki: Tenkyou no Alderamin',
#   'titen': 'Alderamin on the Sky',
#   'titjp': 'ねじ巻き精霊戦記 天鏡のアルデラミン',
#   'theme': 'Action, Adventure, Fantasy',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/11/79531l.jpg',
#   'semes': '16W',
#   'progr': '13/13',
#   'vdate': '15.02.2017',
#   'statu': 'F'},
#  {'index': '44',
#   'malid': '27989',
#   'title': 'Hibike! Euphonium',
#   'titen': 'Sound! Euphonium',
#   'titjp': '響け！ユーフォニアム',
#   'theme': 'Drama',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/6/72445l.jpg',
#   'semes': '17W',
#   'progr': '13/13',
#   'vdate': '14.03.2018',
#   'statu': 'F'},
#  {'index': '49',
#   'malid': '34599',
#   'title': 'Made in Abyss',
#   'titen': 'Made in Abyss',
#   'titjp': 'メイドインアビス',
#   'theme': 'Adventure, Drama, Fantasy, Mystery, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/6/86733l.jpg',
#   'semes': '17S',
#   'progr': '13/13',
#   'vdate': '29.11.2017',
#   'statu': 'F'},
#  {'index': '52',
#   'malid': '35839',
#   'title': 'Sora yori mo Tooi Basho',
#   'titen': 'A Place Further Than The Universe',
#   'titjp': '宇宙よりも遠い場所',
#   'theme': 'Adventure, Comedy, Drama',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/6/89879l.jpg',
#   'semes': '18S',
#   'progr': '13/13',
#   'vdate': '20.06.2018',
#   'statu': 'F'},
#  {'index': '59',
#   'malid': '37497',
#   'title': 'Irozuku Sekai no Ashita kara',
#   'titen': 'Iroduku: The World in Colors',
#   'titjp': '色づく世界の明日から',
#   'theme': 'Drama, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1424/93855l.jpg',
#   'semes': '18W',
#   'progr': '13/13',
#   'vdate': '27.02.2019',
#   'statu': 'F'},
#  {'index': '74',
#   'malid': '226',
#   'title': 'Elfen Lied',
#   'titen': 'Elfen Lied',
#   'titjp': 'エルフェンリート',
#   'theme': 'Action, Drama, Horror, Romance, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/10/6883l.jpg',
#   'semes': '19W',
#   'progr': '13/13',
#   'vdate': '01.07.2020',
#   'statu': 'F'},
#  {'index': '75',
#   'malid': '40046',
#   'title': 'Id:Invaded',
#   'titen': 'ID: INVADED',
#   'titjp': 'ID:INVADED イド:インヴェイデッド',
#   'theme': 'Mystery, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1889/105337l.jpg',
#   'semes': '19W',
#   'progr': '13/13',
#   'vdate': '06.05.2020',
#   'statu': 'F'},
#  {'index': '86',
#   'malid': '22147',
#   'title': 'Amagi Brilliant Park',
#   'titen': 'Amagi Brilliant Park',
#   'titjp': '甘城ブリリアントパーク',
#   'theme': 'Comedy, Drama, Fantasy',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/85435l.jpg',
#   'semes': '20W',
#   'progr': '13/13',
#   'vdate': '17.02.2021',
#   'statu': 'F'},
#  {'index': '64',
#   'malid': '849',
#   'title': 'Suzumiya Haruhi no Yuuutsu',
#   'titen': 'The Melancholy of Haruhi Suzumiya',
#   'titjp': '涼宮ハルヒの憂鬱',
#   'theme': 'Comedy, Mystery, Sci-Fi, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/75901l.jpg',
#   'semes': '19S',
#   'progr': '14/14',
#   'vdate': '08.01.2020',
#   'statu': 'F'},
#  {'index': '2',
#   'malid': '11887',
#   'title': 'Kokoro Connect',
#   'titen': 'Kokoro Connect',
#   'titjp': 'ココロコネクト',
#   'theme': 'Comedy, Drama, Romance, Slice of Life, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/2/39665l.jpg',
#   'semes': '13W',
#   'progr': '17/13',
#   'vdate': '09.04.2014',
#   'statu': 'F'},
#  {'index': '95',
#   'malid': '41025',
#   'title': 'Fumetsu no Anata e',
#   'titen': 'To Your Eternity',
#   'titjp': '不滅のあなたへ',
#   'theme': 'Adventure, Drama, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1880/118484l.jpg',
#   'semes': '21S',
#   'progr': '20/20',
#   'vdate': '20.10.2021',
#   'statu': 'F'},
#  {'index': '27',
#   'malid': '13601',
#   'title': 'Psycho-Pass',
#   'titen': 'Psycho-Pass',
#   'titjp': 'サイコパス',
#   'theme': 'Action, Sci-Fi, Suspense',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/43399l.jpg',
#   'semes': '15W',
#   'progr': '22/22',
#   'vdate': '16.03.2016',
#   'statu': 'F'},
#  {'index': '41',
#   'malid': '12189',
#   'title': 'Hyouka',
#   'titen': 'Hyouka',
#   'titjp': '氷菓',
#   'theme': 'Mystery, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/13/50521l.jpg',
#   'semes': '17S',
#   'progr': '22/22',
#   'vdate': '08.11.2017',
#   'statu': 'F'},
#  {'index': '43',
#   'malid': '34561',
#   'title': 'Re:Creators',
#   'titen': 'Re:CREATORS',
#   'titjp': 'Re:CREATORS 〈レクリエイターズ〉',
#   'theme': 'Action, Fantasy, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/11/85469l.jpg',
#   'semes': '17S',
#   'progr': '22/22',
#   'vdate': '18.10.2017',
#   'statu': 'F'},
#  {'index': '16',
#   'malid': '1210',
#   'title': 'NHK ni Youkoso!',
#   'titen': 'Welcome to the N.H.K.',
#   'titjp': 'N・H・Kにようこそ！',
#   'theme': 'Comedy, Drama, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/3/52675l.jpg',
#   'semes': '14W',
#   'progr': '24/24',
#   'vdate': '08.04.2015',
#   'statu': 'F'},
#  {'index': '29',
#   'malid': '25835',
#   'title': 'Shirobako',
#   'titen': 'Shirobako',
#   'titjp': 'SHIROBAKO',
#   'theme': 'Comedy, Drama',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1918/93511l.jpg',
#   'semes': '16S',
#   'progr': '24/24',
#   'vdate': '21.09.2016',
#   'statu': 'F'},
#  {'index': '45',
#   'malid': '71',
#   'title': 'Full Metal Panic!',
#   'titen': 'Full Metal Panic!',
#   'titjp': 'フルメタル・パニック！',
#   'theme': 'Action, Comedy, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/2/75259l.jpg',
#   'semes': '17W',
#   'progr': '24/24',
#   'vdate': '23.05.2018',
#   'statu': 'F'},
#  {'index': '47',
#   'malid': '35062',
#   'title': 'Mahoutsukai no Yome',
#   'titen': "The Ancient Magus' Bride",
#   'titjp': '魔法使いの嫁',
#   'theme': 'Fantasy, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/3/88476l.jpg',
#   'semes': '17W',
#   'progr': '24/24',
#   'vdate': '16.05.2018',
#   'statu': 'F'},
#  {'index': '56',
#   'malid': '9253',
#   'title': 'Steins;Gate',
#   'titen': 'Steins;Gate',
#   'titjp': 'STEINS;GATE',
#   'theme': 'Drama, Sci-Fi, Suspense',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/73199l.jpg',
#   'semes': '18S',
#   'progr': '24/24',
#   'vdate': '05.09.2018',
#   'statu': 'F'},
#  {'index': '61',
#   'malid': '37520',
#   'title': 'Dororo',
#   'titen': 'Dororo',
#   'titjp': 'どろろ',
#   'theme': 'Action, Adventure, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1879/100467l.jpg',
#   'semes': '18W',
#   'progr': '24/24',
#   'vdate': '14.08.2019',
#   'statu': 'F'},
#  {'index': '69',
#   'malid': '37521',
#   'title': 'Vinland Saga',
#   'titen': 'Vinland Saga',
#   'titjp': 'ヴィンランド・サガ',
#   'theme': 'Action, Adventure, Drama',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1500/103005l.jpg',
#   'semes': '19S',
#   'progr': '24/24',
#   'vdate': '26.02.2020',
#   'statu': 'F'},
#  {'index': '76',
#   'malid': '18679',
#   'title': 'Kill la Kill',
#   'titen': 'KILL la KILL',
#   'titjp': 'キルラキル',
#   'theme': 'Action, Comedy, Ecchi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1464/111943l.jpg',
#   'semes': '19W',
#   'progr': '24/24',
#   'vdate': '03.06.2020',
#   'statu': 'F'},
#  {'index': '77',
#   'malid': '10721',
#   'title': 'Mawaru Penguindrum',
#   'titen': 'Penguindrum',
#   'titjp': '輪るピングドラム',
#   'theme': 'Avant Garde, Comedy, Drama, Mystery',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/30238l.jpg',
#   'semes': '20S',
#   'progr': '24/24',
#   'vdate': '04.11.2020',
#   'statu': 'F'},
#  {'index': '99',
#   'malid': '46093',
#   'title': 'Shiroi Suna no Aquatope',
#   'titen': 'The Aquatope on White Sand',
#   'titjp': '白い砂のアクアトープ',
#   'theme': 'Drama, Slice of Life',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1932/114952l.jpg',
#   'semes': '21S',
#   'progr': '24/24',
#   'vdate': '05.01.2022',
#   'statu': 'F'},
#  {'index': '10',
#   'malid': '13125',
#   'title': 'Shinsekai yori',
#   'titen': 'From the New World',
#   'titjp': '新世界より',
#   'theme': 'Drama, Horror, Mystery, Sci-Fi, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/12/36775l.jpg',
#   'semes': '14S',
#   'progr': '25/25',
#   'vdate': '06.08.2014',
#   'statu': 'F'},
#  {'index': '22',
#   'malid': '6746',
#   'title': 'Durarara!!',
#   'titen': 'Durarara!!',
#   'titjp': 'デュラララ!!',
#   'theme': 'Action, Mystery, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/10/71772l.jpg',
#   'semes': '15S',
#   'progr': '25/24',
#   'vdate': '28.10.2015',
#   'statu': 'F'},
#  {'index': '33',
#   'malid': '33489',
#   'title': 'Little Witch Academia (TV)',
#   'titen': 'Little Witch Academia',
#   'titjp': 'リトルウィッチアカデミア',
#   'theme': 'Adventure, Comedy, Fantasy',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/13/83934l.jpg',
#   'semes': '16W',
#   'progr': '25/25',
#   'vdate': '16.08.2017',
#   'statu': 'F'},
#  {'index': '39',
#   'malid': '31240',
#   'title': 'Re:Zero kara Hajimeru Isekai Seikatsu',
#   'titen': 'Re:ZERO -Starting Life in Another World-',
#   'titjp': 'Re：ゼロから始める異世界生活',
#   'theme': 'Drama, Fantasy, Suspense',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/11/79410l.jpg',
#   'semes': '16W',
#   'progr': '25/25',
#   'vdate': '08.02.2017',
#   'statu': 'F'},
#  {'index': '8',
#   'malid': '7054',
#   'title': 'Kaichou wa Maid-sama!',
#   'titen': 'Maid Sama!',
#   'titjp': '会長はメイド様!',
#   'theme': 'Comedy, Romance',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/6/25254l.jpg',
#   'semes': '14S',
#   'progr': '26/26',
#   'vdate': '03.09.2014',
#   'statu': 'F'},
#  {'index': '15',
#   'malid': '12029',
#   'title': 'Uchuu Senkan Yamato 2199',
#   'titen': 'Star Blazers: Space Battleship Yamato 2199',
#   'titjp': '宇宙戦艦ヤマト2199',
#   'theme': 'Action, Drama, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/2/36607l.jpg',
#   'semes': '14W',
#   'progr': '26/26',
#   'vdate': '03.06.2015',
#   'statu': 'F'},
#  {'index': '38',
#   'malid': '329',
#   'title': 'Planetes',
#   'titen': 'Planetes',
#   'titjp': 'プラネテス',
#   'theme': 'Drama, Romance, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/8/50463l.jpg',
#   'semes': '16W',
#   'progr': '26/26',
#   'vdate': '10.05.2017',
#   'statu': 'F'},
#  {'index': '48',
#   'malid': '457',
#   'title': 'Mushishi',
#   'titen': 'Mushi-Shi',
#   'titjp': '蟲師',
#   'theme': 'Adventure, Fantasy, Mystery, Slice of Life, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/2/73862l.jpg',
#   'semes': '17W',
#   'progr': '26/26',
#   'vdate': '06.06.2018',
#   'statu': 'F'},
#  {'index': '54',
#   'malid': '467',
#   'title': 'Koukaku Kidoutai: Stand Alone Complex',
#   'titen': 'Ghost in the Shell: Stand Alone Complex',
#   'titjp': '攻殻機動隊 STAND ALONE COMPLEX',
#   'theme': 'Action, Sci-Fi',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/11/50857l.jpg',
#   'semes': '18W',
#   'progr': '26/26',
#   'vdate': '10.04.2019',
#   'statu': 'F'},
#  {'index': '55',
#   'malid': '10620',
#   'title': 'Mirai Nikki (TV)',
#   'titen': 'The Future Diary',
#   'titjp': '未来日記',
#   'theme': 'Action, Mystery, Supernatural, Suspense',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/13/33465l.jpg',
#   'semes': '18S',
#   'progr': '26/26',
#   'vdate': '07.11.2018',
#   'statu': 'F'},
#  {'index': '70',
#   'malid': '38000',
#   'title': 'Kimetsu no Yaiba',
#   'titen': 'Demon Slayer: Kimetsu no Yaiba',
#   'titjp': '鬼滅の刃',
#   'theme': 'Action, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/1286/99889l.jpg',
#   'semes': '19S',
#   'progr': '26/26',
#   'vdate': '06.11.2019',
#   'statu': 'F'},
#  {'index': '80',
#   'malid': '14719',
#   'title': 'JoJo no Kimyou na Bouken (TV)',
#   'titen': "JoJo's Bizarre Adventure",
#   'titjp': 'ジョジョの奇妙な冒険',
#   'theme': 'Action, Adventure, Supernatural',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/3/40409l.jpg',
#   'semes': '20S',
#   'progr': '26/26',
#   'vdate': '30.09.2020',
#   'statu': 'F'},
#  {'index': '57',
#   'malid': '5060',
#   'title': 'Hetalia Axis Powers',
#   'titen': 'Hetalia Axis Powers',
#   'titjp': 'ヘタリア Axis Powers',
#   'theme': 'Comedy',
#   'imurl': 'https://cdn.myanimelist.net/images/anime/5/75791l.jpg',
#   'semes': '18S',
#   'progr': '52/52',
#   'vdate': '20.02.2019',
#   'statu': 'F'}]

# %%
# Out:
# 20140402

# %%
import json
from time import sleep
import datetime
from datetime import *
import shutil
from time import time
from threading import Thread

try:
    from mal import config
    from mal import Anime
    from mal import AnimeSearch
    config.TIMEOUT = 20  # Import level config
except:
    print("MAL-Api nicht gefunden. Installieren mit 'pip install -U mal-api'")
    exit()


#Hilfsfunktionen Y



def loadjson():
    try:
        with open('archive.json', encoding="utf-8-sig") as f:
            data = json.loads(f.read())
    except:
        with open('archive.json', encoding="utf-8-sig") as f:
            data = json.loads(f.read()[f.read().index("["):])

    try:
        with open('dates.json', encoding="utf-8-sig") as f:
            dates = json.loads(f.read())
    except:
        with open('dates.json', encoding="utf-8-sig") as f:
            dates = json.loads(f.read()[f.read().index("["):])

    if len(data)*len(dates) != 0:
        print("okay. Daten geladen")
        return data, dates
    else:
        print("Fehler beim Daten laden")
        exit()

        
time_continue = time()
locked = False
def getAnime(malid,i=0):
    global time_continue
    global locked
    global head_thread
    time_start = time()
    maldata = None
    while maldata is None:
        sleep(1)
        timeout = time_continue-time()
        while locked: #while blocked
            if i == head_thread: #only head should test if unblocked
                if time_continue < time():
                    print("")
                    break 
                else:
                    print(".", end="")   
                    sleep(timeout/75)
            else:
                sleep(5)
                
        try:
            maldata = Anime(malid, timeout=10)
        except Exception as e:
            print("")
            locked = True
            timeout = min(max((time()-time_start)//10*10,10),1200) 
            time_continue = time() + timeout
            #print(f"Fehler: {e}  Versuche nochmal in {int(timeout)} sec..")
            print(f"[{i}] {e}, wait {int(timeout)}s")
    locked = False    
    time_continue = time() #reset timeout if successful
    return maldata


def one_cleanup(old, clean, i, mal):
    try:
        if mal: #force update from mal
            a=1/0 #go to except
        if min([len(str(s)) for s in list(old.values())])==0: #missing entries
            a=1/0
        if old["progr"][-2]=="?": #unknown episode count
            a=1/0 
        #load old data, maybe there are missing keys
        tmp = {"index":old["index"], "malid":old["malid"], "title":old["title"], "titen":old["titen"], "titjp":old["titjp"],"theme":old["theme"],"imurl":old["imurl"],"semes":old["semes"],"progr":old["progr"],"vdate":old["vdate"],"statu":old["statu"]}
    except Exception as es:
        if not mal: 
            print(f"Ungültiger Eintrag (id:{old['malid']}) entdeckt, lade neu von MAL.. ({es})")

        maldata = getAnime(old["malid"],i)

        tmp = {"index":old["index"], 
               "malid":old["malid"],
               "title":maldata.title,
               "titen":maldata.title_english,
               "titjp":maldata.title_japanese,
               "theme":", ".join(maldata.genres),
               "imurl":maldata.image_url.replace(".jpg","l.jpg").replace("ll.jpg","l.jpg"), #get large picture
               "semes":old["semes"],
               "progr":("00"+old["progr"][:2].replace("/",""))[-2:]+"/"+("00"+str(maldata.episodes).replace("None","??"))[-2:],
               "vdate":old["vdate"],
               "statu":old["statu"]
               }
        #leere Einträge verhindern
        if tmp["titen"] in ["null", None, False, ""]:
            tmp["titen"] = tmp["title"]
        if tmp["theme"] in ["null", None, False, ""]:
            tmp["theme"] = " "
    #print("")
    #print(f"{tmp['index']} ", end="")
    print(f"{tmp['title']}\n", end="") 
    #print(tmp["titen"])
    #print(tmp["titjp"])
    #print(tmp["theme"])
    #print(tmp["statu"], tmp["progr"])
    #print("")
    #print("")
    clean[i] = tmp
    
def sort_index(entry):
    if entry["statu"] == "W":
        return 0
    else:
        return int(entry["index"])
        #return int(entry["progr"][:2])
        #return int("".join(entry["vdate"].split(".")[::-1]))
    
head_thread = 0
def list_cleanup(data, mal=False):
    clean = [{} for i in data]
    threads = []
    
    for i in range(len(data)):
        #threads.append(Thread(target=call_script, args=(11.0,)))
        threads.append(Thread(target=one_cleanup, args = (data[i], clean, i, mal)))
     
    if mal:
        print("API request sent, waiting for replies:")
    
    for t in threads:
        sleep(.05)
        t.start()
        
    for i in range(len(threads)):
        global head_thread
        head_thread = i
        threads[i].join()
        
    clean = sorted(clean, key=sort_index)
    return clean

def list_statusupdate(data, flag_needsort=False):

    print("Update-Datum eingeben mit Format: 31.01.2022 >> '3101[2022]' (Punkte und Jahr optional)")
    date = input()

    if len(date)>=4 and len(date)<=6:
        date += str(datetime.now().year)
    if len(date)==8:
        date = date[:2]+"."+date[2:4]+"."+date[4:]

    print("Datum: "+date)
    print("")
    print("STATUS UPDATEN: (Eingabe optional)")
    print("")

    for i in range(len(data)):
        if data[i]["statu"]=="W":
            print("Titel:", data[i]["title"])
            print("Folge:", data[i]["progr"])
            inc = input("increment:  +")
            sta = input("status change (W/F/D):")
            print("")
            if not inc in [None,"null","","0",0,"-0"]:
                try:
                    data[i]["progr"]=("00"+str(int(data[i]["progr"][:2])+int(inc)))[-2:]+data[i]["progr"][2:]
                    data[i]["vdate"]=date
                except:
                    print(f"ERROR: '{data[i]['progr']}' + '{inc}' kein gültiges increment")
                    print("")
            if sta!="":
                if sta in ["W","F","D"]:
                    data[i]["statu"] = sta
                    data[i]["vdate"]=date
                    flag_needsort = True
                else:
                    print(f"ERROR: '{sta}' kein gültiger Status")
                    print("")
            print("")

    print("Programm:") 

    ids = []
    for i in range(len(data)):
        if data[i]["statu"]=="W":
            ids.append(i)

    for i,j in zip(ids,range(len(ids))):
         print(j, "--", data[i]["title"])
    print("Neue Reihenfolge eingeben mit Format '0123': ")
    rf = input()
    if rf != "": #falls neue reihenfolge
        tmp = []
        if sorted(rf) == [str(k) for k in range(len(ids))]:
            for i in rf:
                tmp.append(data[ids[int(i)]])
            for i in range(len(ids)):
                data[sorted(ids)[i]] = tmp[i]
        else:
            print("")
            print("ERROR: Reihenfolge ist ungültig!")

    print("")
    print("FERTIG")
    if flag_needsort:
        print("Sortieren notwendig...")
        sleep(3)
        data = list_cleanup(data, mal = False)
    return data

def list_hinzufuegen(data):
    print("NEUEN ANIME HINZUFÜGEN/ALTEN WIEDERBELEBEN:")
    malid = input("MAL-ID (oder Titel für Suche):")
    maldata = None
    try:
        maldata = Anime(malid)
    except:
        print("")
        print("ID ungültig. Suchergebnisse:")
        try:
            search = AnimeSearch(malid)
            for i in range(min(10,len(search.results))):
                print(f'{(" "+str(i+1))[-2:]} -- {search.results[i].title} ({search.results[i].type})')
            i = input("Position: ")
            malid = search.results[int(i)-1].mal_id
            maldata = Anime(malid, timeout=10)
        except:
            print("")
            print("Suche nicht erfolgreich.")

    if maldata != None:
        print("")
        flag = False
        for i in range(len(data)):
            if data[i]["malid"] == malid:
                flag = True
                index = i
        if flag:
            print(f"Anime schon vorhanden. '{maldata.title}' wird wieder aktiviert.")
            data[i]["statu"] = "W"
        else:
            print(f"ID okay. '{maldata.title}' wird hinzugefügt")
            #semester
            if datetime.now().month in [4,5,6,7,8,9]:
                ts = str(datetime.now().year)[-2:]+"S"
            else:
                if datetime.now().month in [10,11,12]:
                    ts = str(datetime.now().year)[-2:]+"W"
                else:
                    ts = str(datetime.now().year-1)[-2:]+"W"
            #neuer eintrag
            tmp = {"index":str(len(data)+1), 
                   "malid":str(malid),
                   "semes":ts,
                   "vdate":"null",
                   "statu":"W",
                   "progr":"00/??"
                   }            
            data.append(tmp)
        print("")
        print("Bereinigung notwendig...")
        sleep(5)
        data = list_cleanup(data, mal=False)
        print("")
        print("Statusupdate notwendig...")
        sleep(5)
        #data = list_statusupdate(data, flag_needsort=True)
    return data

def dates_sort(dates):
    for i in range(len(dates)):
        for j in range(i+1,len(dates)):
            if((datetime.fromisoformat(dates[i]["date"]).timestamp()-datetime.fromisoformat(dates[j]["date"]).timestamp())/(60*60*24) > 0):
                tmp = dates[i].copy()
                dates[i] = dates[j].copy()
                dates[j] = tmp
    return dates    

def dates_next(dates):
    dates = dates_sort(dates)
    i = len(dates)
    #letzte Sitzung finden
    while True:
        i+=-1
        if(dates[i]["type"]!="A" or dates[i]["type"]=="B" or dates[i]["type"]=="C" or dates[i]["type"]=="D"):
            break

    d = datetime.fromisoformat(dates[i]["date"])

    #Sitzung 5 mal kopieren
    for j in range(1,5):
        tmp_d = d + timedelta(days=7*j)
        print("Datum für Sitzung:", str(tmp_d)[:16])
        ny = input("bestätigen? y/n? ")
        if ny in ["y","Y","j","J","1"]:
            tmp =  dates[i].copy()
            tmp["date"] = tmp_d.isoformat().replace(":00+","+")
            print("okay. Hinzugefügt:", tmp["title"], f"({tmp['type']}) @", str(tmp_d)[:16])
            dates.append(tmp)
        print("")  
    print("") 
    return dates

def dates_new(dates):
    print("(Zeitformat:", dates[-1]["date"].replace("+01:00",")"))
    d = input("Termin eingeben: ")
    d = d + "+01:00"
    try:
        datetime.fromisoformat(d)

        tmp = dates[-1].copy()
        tmp["date"] = d

        tmp["title"] = input("Titel: ")
        tmp["type"] = input("Typ Normal (A/B) oder Event (S): ")
        if not tmp["type"] in ["A","B","S"]:
            a=1/0
        dates.append(tmp)
        print("okay. Hinzugefügt:", tmp["title"], f"({tmp['type']}) @", str(datetime.fromisoformat(tmp["date"]))[:16])
    except:
        print("ERROR: Zeit/Termintyp ungültig")
    print("")
    return dates_sort(dates)


def savejson(data, dates):
    try: #backup
        shutil.copy('archive.json', 'backup/archive'+datetime.now().isoformat()[:19].replace(":","-")+'.json')
    except:
        pass
    #save
    try:
        with open("archive.json", "w", encoding="utf-8") as outfile:
            json.dump(data, outfile, indent = 4)
        with open("dates.json", "w", encoding="utf-8") as outfile:
            json.dump(dates_sort(dates), outfile, indent = 4)
        print("okay. gespeichert")
    except Exception as e:
        print("ERROR beim speichern:", e)


### START
print("START\n\n\n")
data,dates = loadjson()

while True:
    print("\n\n\n")
    print("    MENÜ:\n---------------")
    print("1 - Watchlist Status Update")
    print("2 - Neuen Anime hinzufügen/reaktivieren")
    print("3 - Neue Termine (letzten kopieren)")
    print("4 - Neuer Termin (einzeln)")
    print("")
    print("6 - SPEICHERN UND BEENDEN")
    print("")
    print("    optional:")
    print("9 - Anime-Liste bereinigen/sortieren")
    print("0 - Anime-Liste komplett neu aufbauen (braucht lange)")
    print("")
    cho = input("wählen:")
    if cho in ["1","2","3","4","6","9","0"]:
        cho = int(cho)
        print("\n\n")
        if cho==1:
            data = list_statusupdate(data, flag_needsort=False)
        if cho==2:
            data = list_hinzufuegen(data)
        if cho==3:
            dates = dates_next(dates)
        if cho==4:
            dates = dates_new(dates)
        if cho==6:
            savejson(data, dates)
            break
        if cho==9:
            data = list_cleanup(data, mal=False)
        if cho==0:
            data = list_cleanup(data, mal=True)
# Out:
# START
#
#
#
# okay. Daten geladen
#
#
#
#
#     MENÜ:
# ---------------
# 1 - Watchlist Status Update
# 2 - Neuen Anime hinzufügen/reaktivieren
# 3 - Neue Termine (letzten kopieren)
# 4 - Neuer Termin (einzeln)
#
# 6 - SPEICHERN UND BEENDEN
#
#     optional:
# 9 - Anime-Liste bereinigen/sortieren
# 0 - Anime-Liste komplett neu aufbauen (braucht lange)
#
# wählen:6
#
#
#
# okay. gespeichert

# %%
Anime(1).aired
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19276/3803743402.py in <module>
# ----> 1 Anime(1).aired
#
# ~\anaconda3\lib\site-packages\mal\_anime.py in __init__(self, mal_id, timeout)
#      49         Anime query by ID
#      50         """
# ---> 51         super().__init__(mal_id, "anime", timeout)
#      52
#      53     def reload(self) -> None:
#
# ~\anaconda3\lib\site-packages\mal\_mal.py in __init__(self, mal_id, mal_type, timeout)
#      13         self._page = self._parse_url(self._url)
#      14         if self._page.find("div", {"class": "display-submit"}) != None:
# ---> 15             raise Exception("Temporarily blocked by MyAnimeList")
#      16         title = self._page.find("meta", property="og:title")["content"]
#      17         if title == "404 Not Found - MyAnimeList.net ":
#
# Exception: Temporarily blocked by MyAnimeList
